# %% [markdown]
# # Proyecto
#
# - Elegir tema
# - Limpieza y transformación: duplicados, tipos, missing
# - Preparación de datos para el modelo:
#   - Selección de variables
#   - Comprobación balanceo - clasificación
#   - Agrupación datos en categorías
#   - Codificación variables categóricas
#   -
#   - SEPARACIÓN EN FEATURE & TARGET
#   - SEPARACIÓN X_train, y_train, X_test, y_test
#   - ESTANDARIZACIÓN
#   -
# - Aplicación Modelos:
#   - Elección modelo y lo guardamos en variables
#   - modelo.fit(X_train_norm, y_train)
#   - pred/score -> métrica
#
#     - KNN (todos), regresión lineal (regresión), regresión logística (clasificación), árbol decisión (todos)
#     - Ensemble: bagging (todos), random forest (todos), Ada Boost (todos), Gradient Boost (todos)
#     - Seleccionar el mejor modelo (o dos modelos)  hasta el momento
#       - Tunear parámetros: grid search (todos) / random search (todos)
#
# ### Nota: lo ideal es tunear parámetros para cada modelo.
#
# - Obtener el mejor modelo que hemos obtenido.
# - Guardar modelo
# - Aplicar modelo sobre datos nuevos
